# %% [markdown]
# #### Perform clustering (Hierarchical, K means clustering and DBSCAN) for the airlines data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from scipy.cluster import hierarchy
from sklearn.cluster import AgglomerativeClustering

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Hierarchical Clustering

# %%
df = pd.read_csv("D:\\Data Science\\Data Science Assignment\\Clustering\\EastWestAirlines.csv", encoding='latin-1')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ### EDA and Visualization

# %%
df.rename(columns={'Award?':'Award', 'ID#':'ID' }, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award              3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
df.describe()
# Out:
#                 ID       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
df.isna().sum()
# Out:
# ID                   0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %% [markdown]
# ### Scaling down the data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x = pd.DataFrame(sc.fit_transform(df.iloc[:,1: ]), columns=df.iloc[:,1: ].columns)
x
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Finding optimal number of clusters using dendograms

# %%
from scipy.cluster import hierarchy

# %%
lk = hierarchy.linkage(x, method='complete')

# %%
dendrogram = hierarchy.dendrogram(lk)
plt.figure(figsize = (150,50))
plt.title('Hierarchical Dendrogram')
plt.show()

# %% [markdown]
# ### Model Buliding

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters=5)

# %%
ylabel = hc.fit_predict(x)
ylabel
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
df['Cluster'] = ylabel
df
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.groupby('Cluster').agg('mean')
# Out:
#                   ID        Balance  Qual_miles  cc1_miles  cc2_miles  \
# Cluster
# 0        1706.626285  116134.226872  367.779736   3.500000   1.000000
# 1        2197.204007   46329.336877    9.028618   1.244072   1.000000
# 2        1765.615385  134880.892308  393.323077   2.430769   1.000000
# 3        2269.372093   68876.581395   23.255814   1.139535   2.348837
# 4        1742.444444  129951.388889   65.666667   3.388889   1.000000
#
#          cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# Cluster
# 0         1.000000  36501.331865    17.958884         376.402349
# 1         1.000000   4868.112428     6.907604         214.812756
# 2         1.000000  36582.169231    29.338462        5915.523077
# 3         1.000000  14689.837209    17.534884         582.627907
# 4         3.722222  86259.888889    26.222222         422.222222
#
#          Flight_trans_12  Days_since_enroll     Award
# Cluster
# 0               1.147577        4699.638767  0.665198
# ...

# %% [markdown]
# ### Visualizing the clusters

# %%
df[df['Cluster']==2]
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 50      51   108137           0          1          1          1         6368
# 65      66    53914           0          3          1          1        33767
# 94      97   185549           0          5          1          1       110859
# 112    115   124198           0          5          1          1        66330
# 121    124   205126           0          5          1          1       126630
# ...    ...      ...         ...        ...        ...        ...          ...
# 3907  3930   126490           0          1          1          1         8808
# 3911  3934    55922        2273          1          1          1         8104
# 3917  3940   130748           0          4          1          1        65510
# 3934  3957    76595           0          1          1          1        10577
# 3950  3973    59650           0          1          1          1         5050
#
# ...

# %%
sns.scatterplot(data=df, x='Balance', y='Cluster', hue='ID')
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ## K-means Clustering

# %%
df2 = pd.read_csv("D:\\Data Science\\Data Science Assignment\\Clustering\\EastWestAirlines.csv", encoding='latin-1')
df2
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ### EDA and Visualization

# %%
df2.rename(columns={'Award?':'Award', 'ID#':'ID' }, inplace= True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award              3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
df2.describe()
# Out:
#                 ID       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Scaling down the data

# %%
x2 = pd.DataFrame(sc.fit_transform(df2.iloc[:,1: ]), columns=df2.iloc[:,1: ].columns)
x2
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Basic Model

# %%
from sklearn.cluster import KMeans
km = KMeans()

# %%
cluster2 = km.fit_predict(x2)
cluster2
# Out:
# array([2, 2, 2, ..., 7, 0, 0])

# %% [markdown]
# ### Finding optimal number of clusters using Elbow Graph

# %%
wcss2 = []

for i in range(1,20):
    km = KMeans(n_clusters=i)
    km.fit_predict(x2)
    wcss2.append(km.inertia_)

# %%
wcss2
# Out:
# [43989.0,
#  35409.51662986131,
#  30899.253324696223,
#  27161.29395482269,
#  24544.64921854807,
#  21470.826322582416,
#  19165.86145865566,
#  17316.68304571841,
#  15967.288679152582,
#  14729.019742919992,
#  13706.795289917265,
#  12946.819693863075,
#  12430.310437162529,
#  11973.015625715283,
#  11453.3740629385,
#  11107.311580215795,
#  10791.084380050288,
#  10354.37076839356,
#  10162.896561313948]

# %%
plt.plot(range(1,20), wcss2)
plt.scatter(range(1, 20), wcss2,color = 'red')
plt.title('ELBOW METHOD')
plt.xlabel('Kvalues')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### Revised Model

# %%
# k-value = 6
km = KMeans(n_clusters=6)
ylabel2 = km.fit_predict(x2)
ylabel2
# Out:
# array([2, 2, 2, ..., 0, 4, 4])

# %%
df2['Cluster2'] = ylabel2
df2
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ### Visualizing the clusters

# %%
df2[df2['Cluster2']==4]
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 1129  1141     1625           0          1          1          1         1375
# 1272  1285    24698           0          1          1          1         1329
# 1311  1324    31484           0          1          1          1         3125
# 1424  1438    22093           0          3          1          1        14857
# 1431  1445    44665           0          1          1          1          333
# ...    ...      ...         ...        ...        ...        ...          ...
# 3993  4016     3974           0          1          1          1          365
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
sns.scatterplot(data=df2, x='Balance', y='Cluster2', hue='ID')
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ## DBSCAN

# %%
df3 = pd.read_csv("D:\\Data Science\\Data Science Assignment\\Clustering\\EastWestAirlines.csv", encoding='latin-1')
df3
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ### EDA and Visualization

# %%
df3.rename(columns={'Award?':'Award', 'ID#':'ID' }, inplace= True)

# %%
df3.describe()
# Out:
#                 ID       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
df3.isna().sum()
# Out:
# ID                   0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award              3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %% [markdown]
# ### Scaling down the data

# %%
x3 = pd.DataFrame(sc.fit_transform(df3.iloc[:,1: ]), columns=df3.iloc[:,1: ].columns)
x3
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Model Building

# %% [markdown]
# #### Iteration 1

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps = 1,min_samples = 5)

# %%
db.fit(x3)
# Out:
# DBSCAN(eps=1)

# %%
db.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
df3['Cluster3'] = db.labels_
df3
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df3.Cluster3.value_counts()
# Out:
#  0    2319
#  1    1093
# -1     554
#  2      13
#  5       9
#  3       6
#  4       5
# Name: Cluster3, dtype: int64

# %% [markdown]
# #### Iteration 2

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps = 0.8,min_samples = 10)

# %%
db.fit(x3)
# Out:
# DBSCAN(eps=0.8, min_samples=10)

# %%
db.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
df3['Cluster3'] = db.labels_
df3
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df3.Cluster3.value_counts()
# Out:
#  0    2183
# -1     912
#  1     896
#  2       8
# Name: Cluster3, dtype: int64

# %% [markdown]
# #### Conclusion:

# %% [markdown]
# 912 outliers
#
# As increased the min_samples there are no clusters after 'cluster2'.

# %% [markdown]
# ### Visualizing the clusters

# %%
df3[df3['Cluster3']==1]
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 7        8    20856           0          1          1          1         5250
# 11      12    96522           0          5          1          1        61105
# 15      16    28495           0          4          1          1        49442
# 16      17    51890           0          4          1          1        48963
# 17      18    13958           0          1          1          1         4291
# ...    ...      ...         ...        ...        ...        ...          ...
# 3987  4010    11933           0          1          1          1          249
# 3989  4012     2622           0          1          1          1         1625
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
#
# ...

# %%
sns.scatterplot(data=df3, x='Balance', y='Cluster3', hue = 'ID')
plt.legend(bbox_to_anchor = (1,1))
plt.show()

# %% [markdown]
# #### Conclusion:

# %% [markdown]
# 1.After performing the Clustering of the Airlines data, we find the models that have better clustering ability is DBSCAN > KMeans > Hierarchical.
#
# 2.The no. of clusters for for the models are - Hierarchical : 5, KMeans : 6, DBSCAN : 4

# %% [markdown]
# ### End
